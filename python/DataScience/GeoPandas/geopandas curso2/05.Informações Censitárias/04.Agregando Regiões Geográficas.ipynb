# %% [markdown]
# # Agregando Regiões Geográficas

# %%
# %matplotlib inline
import geopandas as gpd

# %%
setor = gpd.read_file('../01.Dados/Mapas/RJ-SETOR/RJ-SETOR.shp')

# %%
setor.plot(color='white', edgecolor='black', figsize=(15, 8))

# %%
setor.head()
# Out:
#       ID1       CD_GEOCODI    TIPO    CD_GEOCODB     NM_BAIRRO CD_GEOCODD  \
# 0  400341  330455705060018  URBANO  330455705004          Caju  330455705
# 1  400342  330455705060019  URBANO  330455705004          Caju  330455705
# 2  400343  330455705060020  URBANO  330455705004          Caju  330455705
# 3  400344  330455705060021  URBANO  330455705004          Caju  330455705
# 4  400347  330455705060024  URBANO  330455705003  Santo Cristo  330455705
#
#        NM_DISTRIT CD_GEOCODS NM_SUBDIST CD_GEOCODM  \
# 0  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557
# 1  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557
# 2  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557
# 3  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557
# 4  RIO DE JANEIRO  330455705  PORTUÁRIA    3304557
#
#                          ...                          V004    V005       V006  \
# 0                        ...                          1.77  687.86  607487.37
# 1                        ...                          2.06  645.95  443290.44
# 2                        ...                          1.72  788.46  532814.72
# 3                        ...                          2.57  635.00  587850.00
# 4                        ...                          2.49  568.02  173698.43
#
#       V007       V008    V009       V010     V011       V012  \
# 0  1162.52  474104.49  468.88  439565.17   993.66  410002.85
# 1   955.47  359529.36  436.96  323403.61   844.44  280771.01
# 2  1042.81  437929.47  536.64  468960.56   971.76  425985.79
# 3  1018.65  551834.99  323.89  379860.88  1008.94  493116.72
# 4   679.01  131792.80  378.96  177655.16   645.64  130200.18
#
#                                             geometry
# 0  POLYGON ((683.349326221016 7469.17768684979, 6...
# 1  POLYGON ((683.3094976400794 7469.213659905473,...
# 2  POLYGON ((683.2982913807748 7469.418253547153,...
# 3  POLYGON ((683.4782944704702 7469.289246539755,...
# 4  POLYGON ((683.8518253829462 7465.621685850603,...
#
# [5 rows x 47 columns]

# %%
setor = setor.to_crs({'init': 'epsg:4326'})
setor_m = setor[['NM_BAIRRO', 'geometry']]

# %%
bairro = setor_m.dissolve(by='NM_BAIRRO')

# %%
bairro
# Out:
#                                                                geometry
# NM_BAIRRO
# Abolição              POLYGON ((-43.2948946607115 -22.88916168148589...
# Acari                 POLYGON ((-43.3388200954628 -22.8265849731976,...
# Alto da Boa Vista     POLYGON ((-43.2937714358462 -22.97985816174459...
# Anchieta              POLYGON ((-43.3853977481138 -22.8268893315428,...
# Andaraí               POLYGON ((-43.2543598934882 -22.93421659196149...
# Anil                  POLYGON ((-43.3305932964059 -22.95753802878729...
# Bancários             (POLYGON ((-43.1693785725445 -22.8004215115191...
# Bangu                 POLYGON ((-43.5057129437459 -22.8679887057448,...
# Barra da Tijuca       (POLYGON ((-43.30795783139229 -23.038683939927...
# Barra de Guaratiba    (POLYGON ((-43.56124784648589 -23.082857851095...
# Barros Filho          POLYGON ((-43.3591443708705 -22.8399774286538,...
# Benfica               POLYGON ((-43.2354236829865 -22.90021259295099...
# Bento Ribeiro         POLYGON ((-43.3607181239461 -22.8784182141082,...
# Bonsucesso            POLYGON ((-43.2573382635351 -22.8752631607771,...
# Botafogo              POLYGON ((-43.1720413202213 -22.9556623466217,...
# Brás de Pina          POLYGON ((-43.3134261383742 -22.83812234256389...
# Cachambi              POLYGON ((-43.2798618188021 -22.8929632320679,...
# Cacuia                (POLYGON ((-43.1748569093396 -22.8383375175486...
# Caju                  (POLYGON ((-43.2093511353287 -22.8917017503289...
# Camorim               POLYGON ((-43.4282923108188 -22.9888421815855,...
# Campinho              POLYGON ((-43.3397348251333 -22.88714561308801...
# Campo Grande          POLYGON ((-43.560973673386 -22.94802328436069,...
# Campo dos Afonsos     POLYGON ((-43.3755016181682 -22.8805653670811,...
# Cascadura             POLYGON ((-43.3300932414191 -22.8925774443611,...
# Catete                POLYGON ((-43.1778079921617 -22.9326166382998,...
# Catumbi               POLYGON ((-43.19529257901709 -22.9231962996837...
# Cavalcanti            POLYGON ((-43.3111843610983 -22.8778913255455,...
# Centro                (POLYGON ((-43.17598224293 -22.8829986326086, ...
# Cidade Nova           POLYGON ((-43.2013926262111 -22.913134584342, ...
# Cidade Universitária  POLYGON ((-43.2173859515666 -22.8704330082943,...
# ...                                                                 ...
# Saúde                 POLYGON ((-43.1811087670424 -22.89729318351958...
# Senador Camará        POLYGON ((-43.47973663972719 -22.8970258304645...
# Senador Vasconcelos   POLYGON ((-43.54273713761629 -22.9038557139848...
# Sepetiba              (POLYGON ((-43.70320568932389 -22.985266049550...
# São Conrado           (POLYGON ((-43.2779837075555 -23.0297792956756...
# São Cristóvão         (POLYGON ((-43.23030780241159 -22.907661990545...
# São Francisco Xavier  POLYGON ((-43.2391810677131 -22.9090090231508,...
# Tanque                POLYGON ((-43.360111472458 -22.9270775388543, ...
# Taquara               POLYGON ((-43.38421538510489 -22.9417792734859...
# Tauá                  POLYGON ((-43.18141116552719 -22.7998154844859...
# Tijuca                POLYGON ((-43.2400259847655 -22.9445105448252,...
# Todos os Santos       POLYGON ((-43.28700227830341 -22.9018464134857...
# Tomás Coelho          POLYGON ((-43.2995082487036 -22.8712367565545,...
# Turiaçu               POLYGON ((-43.3451578149492 -22.86751399951069...
# Urca                  (POLYGON ((-43.1484871981795 -22.935433094267,...
# Vargem Grande         POLYGON ((-43.4997690119142 -23.01983432244089...
# Vargem Pequena        (POLYGON ((-43.44893121478889 -23.002917822718...
# Vasco da Gama         POLYGON ((-43.22967892959602 -22.8914413703290...
# Vaz Lobo              POLYGON ((-43.3242581152285 -22.8646283849312,...
# Vicente de Carvalho   POLYGON ((-43.3077573375087 -22.8589418286394,...
# Vidigal               POLYGON ((-43.2335663730269 -22.99618690922409...
# Vigário Geral         POLYGON ((-43.3173273099891 -22.8185666188521,...
# Vila Isabel           POLYGON ((-43.2580634958779 -22.9200540399484,...
# Vila Kosmos           POLYGON ((-43.3077573375087 -22.8589418286394,...
# Vila Militar          POLYGON ((-43.4043827061846 -22.8845607318064,...
# Vila Valqueire        POLYGON ((-43.3672154790379 -22.8966403108552,...
# Vila da Penha         POLYGON ((-43.3155115929637 -22.84892203687169...
# Vista Alegre          POLYGON ((-43.3090261131271 -22.8330319759195,...
# Zumbi                 POLYGON ((-43.1755123623007 -22.8238010958168,...
# Água Santa            POLYGON ((-43.3024515935387 -22.9122946775479,...
#
# [160 rows x 1 columns]

# %%
bairro.plot(color='white', edgecolor='black', figsize=(15, 8))

# %%
setor_m = setor[['NM_BAIRRO', 'geometry', 'V002']]

# %%
bairro = setor_m.dissolve(by='NM_BAIRRO', aggfunc='sum')

# %%
bairro
# Out:
#                                                                geometry  \
# NM_BAIRRO
# Abolição              POLYGON ((-43.2948946607115 -22.88916168148589...
# Acari                 POLYGON ((-43.3388200954628 -22.8265849731976,...
# Alto da Boa Vista     POLYGON ((-43.2937714358462 -22.97985816174459...
# Anchieta              POLYGON ((-43.3853977481138 -22.8268893315428,...
# Andaraí               POLYGON ((-43.2543598934882 -22.93421659196149...
# Anil                  POLYGON ((-43.3305932964059 -22.95753802878729...
# Bancários             (POLYGON ((-43.1693785725445 -22.8004215115191...
# Bangu                 POLYGON ((-43.5057129437459 -22.8679887057448,...
# Barra da Tijuca       (POLYGON ((-43.30795783139229 -23.038683939927...
# Barra de Guaratiba    (POLYGON ((-43.56124784648589 -23.082857851095...
# Barros Filho          POLYGON ((-43.3591443708705 -22.8399774286538,...
# Benfica               POLYGON ((-43.2354236829865 -22.90021259295099...
# Bento Ribeiro         POLYGON ((-43.3607181239461 -22.8784182141082,...
# Bonsucesso            POLYGON ((-43.2573382635351 -22.8752631607771,...
# Botafogo              POLYGON ((-43.1720413202213 -22.9556623466217,...
# Brás de Pina          POLYGON ((-43.3134261383742 -22.83812234256389...
# Cachambi              POLYGON ((-43.2798618188021 -22.8929632320679,...
# Cacuia                (POLYGON ((-43.1748569093396 -22.8383375175486...
# Caju                  (POLYGON ((-43.2093511353287 -22.8917017503289...
# Camorim               POLYGON ((-43.4282923108188 -22.9888421815855,...
# Campinho              POLYGON ((-43.3397348251333 -22.88714561308801...
# Campo Grande          POLYGON ((-43.560973673386 -22.94802328436069,...
# Campo dos Afonsos     POLYGON ((-43.3755016181682 -22.8805653670811,...
# Cascadura             POLYGON ((-43.3300932414191 -22.8925774443611,...
# Catete                POLYGON ((-43.1778079921617 -22.9326166382998,...
# Catumbi               POLYGON ((-43.19529257901709 -22.9231962996837...
# Cavalcanti            POLYGON ((-43.3111843610983 -22.8778913255455,...
# Centro                (POLYGON ((-43.17598224293 -22.8829986326086, ...
# Cidade Nova           POLYGON ((-43.2013926262111 -22.913134584342, ...
# Cidade Universitária  POLYGON ((-43.2173859515666 -22.8704330082943,...
# ...                                                                 ...
# Saúde                 POLYGON ((-43.1811087670424 -22.89729318351958...
# Senador Camará        POLYGON ((-43.47973663972719 -22.8970258304645...
# Senador Vasconcelos   POLYGON ((-43.54273713761629 -22.9038557139848...
# Sepetiba              (POLYGON ((-43.70320568932389 -22.985266049550...
# São Conrado           (POLYGON ((-43.2779837075555 -23.0297792956756...
# São Cristóvão         (POLYGON ((-43.23030780241159 -22.907661990545...
# São Francisco Xavier  POLYGON ((-43.2391810677131 -22.9090090231508,...
# Tanque                POLYGON ((-43.360111472458 -22.9270775388543, ...
# Taquara               POLYGON ((-43.38421538510489 -22.9417792734859...
# Tauá                  POLYGON ((-43.18141116552719 -22.7998154844859...
# Tijuca                POLYGON ((-43.2400259847655 -22.9445105448252,...
# Todos os Santos       POLYGON ((-43.28700227830341 -22.9018464134857...
# Tomás Coelho          POLYGON ((-43.2995082487036 -22.8712367565545,...
# Turiaçu               POLYGON ((-43.3451578149492 -22.86751399951069...
# Urca                  (POLYGON ((-43.1484871981795 -22.935433094267,...
# Vargem Grande         POLYGON ((-43.4997690119142 -23.01983432244089...
# Vargem Pequena        (POLYGON ((-43.44893121478889 -23.002917822718...
# Vasco da Gama         POLYGON ((-43.22967892959602 -22.8914413703290...
# Vaz Lobo              POLYGON ((-43.3242581152285 -22.8646283849312,...
# Vicente de Carvalho   POLYGON ((-43.3077573375087 -22.8589418286394,...
# Vidigal               POLYGON ((-43.2335663730269 -22.99618690922409...
# Vigário Geral         POLYGON ((-43.3173273099891 -22.8185666188521,...
# Vila Isabel           POLYGON ((-43.2580634958779 -22.9200540399484,...
# Vila Kosmos           POLYGON ((-43.3077573375087 -22.8589418286394,...
# Vila Militar          POLYGON ((-43.4043827061846 -22.8845607318064,...
# Vila Valqueire        POLYGON ((-43.3672154790379 -22.8966403108552,...
# Vila da Penha         POLYGON ((-43.3155115929637 -22.84892203687169...
# Vista Alegre          POLYGON ((-43.3090261131271 -22.8330319759195,...
# Zumbi                 POLYGON ((-43.1755123623007 -22.8238010958168,...
# Água Santa            POLYGON ((-43.3024515935387 -22.9122946775479,...
#
#                           V002
# NM_BAIRRO
# Abolição               11356.0
# Acari                  26967.0
# Alto da Boa Vista       9189.0
# Anchieta               55634.0
# Andaraí                39325.0
# Anil                   24156.0
# Bancários              12512.0
# Bangu                 240666.0
# Barra da Tijuca       135920.0
# Barra de Guaratiba      3545.0
# Barros Filho           14046.0
# Benfica                23698.0
# Bento Ribeiro          43691.0
# Bonsucesso             18341.0
# Botafogo               82602.0
# Brás de Pina           59218.0
# Cachambi               42093.0
# Cacuia                 10997.0
# Caju                   20289.0
# Camorim                 1953.0
# Campinho               10137.0
# Campo Grande          327905.0
# Campo dos Afonsos       1365.0
# Cascadura              34347.0
# Catete                 24009.0
# Catumbi                12482.0
# Cavalcanti             16138.0
# Centro                 40834.0
# Cidade Nova             5386.0
# Cidade Universitária    1475.0
# ...                        ...
# Saúde                   2741.0
# Senador Camará        105423.0
# Senador Vasconcelos    30570.0
# Sepetiba               56416.0
# São Conrado            10980.0
# São Cristóvão          24602.0
# São Francisco Xavier    8307.0
# Tanque                 37618.0
# Taquara               101739.0
# Tauá                   29501.0
# Tijuca                163095.0
# Todos os Santos        24608.0
# Tomás Coelho           22671.0
# Turiaçu                17245.0
# Urca                    6760.0
# Vargem Grande          14010.0
# Vargem Pequena         27212.0
# Vasco da Gama          15421.0
# Vaz Lobo               15167.0
# Vicente de Carvalho    24959.0
# Vidigal                12788.0
# Vigário Geral          41539.0
# Vila Isabel            85770.0
# Vila Kosmos            18265.0
# Vila Militar           13147.0
# Vila Valqueire         32232.0
# Vila da Penha          25462.0
# Vista Alegre            8622.0
# Zumbi                   2016.0
# Água Santa              7594.0
#
# [160 rows x 2 columns]

# %%
setor_m['V002'].sum()
# Out:
# 6283486.0

# %%
bairro['V002'].sum()
# Out:
# 6283486.0

# %%
bairro = bairro.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')

# %%
bairro.crs
# Out:
# '+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs'

# %%
bairro.reset_index(inplace=True)

# %%
bairro
# Out:
#                 NM_BAIRRO                                           geometry  \
# 0                Abolição  POLYGON ((674.9022762714081 7467.737467256332,...
# 1                   Acari  POLYGON ((670.4737581541291 7474.718121014207,...
# 2       Alto da Boa Vista  POLYGON ((674.9009368222775 7457.693019411037,...
# 3                Anchieta  POLYGON ((665.6925899602344 7474.737453569923,...
# 4                 Andaraí  POLYGON ((679.0018532964939 7462.699607526311,...
# 5                    Anil  POLYGON ((671.1537797079652 7460.208007124154,...
# 6               Bancários  (POLYGON ((687.9020783304517 7477.409716109432...
# 7                   Bangu  POLYGON ((653.2975451159319 7470.316770138124,...
# 8         Barra da Tijuca  (POLYGON ((673.3712145994602 7451.195874101197...
# 9      Barra de Guaratiba  (POLYGON ((647.366168658181 7446.582330559718,...
# 10           Barros Filho  POLYGON ((668.3711499653929 7473.258510326782,...
# 11                Benfica  POLYGON ((680.9892150870263 7466.441863151127,...
# 12          Bento Ribeiro  POLYGON ((668.1623113944885 7469.003772370553,...
# 13             Bonsucesso  POLYGON ((678.7736804531771 7469.231400781341,...
# 14               Botafogo  POLYGON ((687.4153996258088 7460.222102314843,...
# 15           Brás de Pina  POLYGON ((673.0656681740697 7473.411025338905,...
# 16               Cachambi  POLYGON ((676.4396862081538 7467.298572680902,...
# 17                 Cacuia  (POLYGON ((687.2877372968051 7473.217977019982...
# 18                   Caju  (POLYGON ((683.6754964839071 7467.352018792834...
# 19                Camorim  POLYGON ((661.0983776986212 7456.852298437026,...
# 20               Campinho  POLYGON ((670.304367892336 7468.013273324455, ...
# 21           Campo Grande  POLYGON ((647.5408899953683 7461.511522250447,...
# 22      Campo dos Afonsos  POLYGON ((666.6428691023942 7468.782820137926,...
# 23              Cascadura  POLYGON ((671.2867444518748 7467.400616627101,...
# 24                 Catete  POLYGON ((686.8556702242917 7462.781491568852,...
# 25                Catumbi  POLYGON ((685.075110101023 7463.846798112508, ...
# 26             Cavalcanti  POLYGON ((673.2453166407498 7469.004713126766,...
# 27                 Centro  (POLYGON ((687.1110462002655 7468.273757827297...
# 28            Cidade Nova  POLYGON ((684.4630228796201 7464.968666765957,...
# 29   Cidade Universitária  POLYGON ((682.8796400546464 7469.717230283156,...
# ..                    ...                                                ...
# 130                 Saúde  POLYGON ((686.5654810365651 7466.697321656682,...
# 131        Senador Camará  POLYGON ((655.9296863736315 7467.074367203072,...
# 132   Senador Vasconcelos  POLYGON ((649.4593941131051 7466.383490721591,...
# 133              Sepetiba  (POLYGON ((632.9198230773047 7457.523825337676...
# 134           São Conrado  (POLYGON ((676.4546841911929 7452.1461032256, ...
# 135         São Cristóvão  (POLYGON ((681.504138829396 7465.610649847385,...
# 136  São Francisco Xavier  POLYGON ((680.5920875698837 7465.472405913526,...
# 137                Tanque  POLYGON ((668.1645236036915 7463.615023589908,...
# 138               Taquara  POLYGON ((665.6743988767026 7462.01447510525, ...
# 139                  Tauá  POLYGON ((686.6675388777403 7477.492075868382,...
# 140                Tijuca  POLYGON ((680.4583556566248 7461.542170430674,...
# 141       Todos os Santos  POLYGON ((675.6956685179971 7466.323451645546,...
# 142          Tomás Coelho  POLYGON ((674.4518478675428 7469.727808502682,...
# 143               Turiaçu  POLYGON ((669.772402387405 7470.193352411593, ...
# 144                  Urca  (POLYGON ((689.8591541063337 7462.432018129757...
# 145         Vargem Grande  POLYGON ((653.7357685397113 7453.49738890367, ...
# 146        Vargem Pequena  (POLYGON ((658.9660606164749 7455.316254936574...
# 147         Vasco da Gama  POLYGON ((681.5902545079616 7467.406070900846,...
# 148              Vaz Lobo  POLYGON ((671.9205891022825 7470.488650876897,...
# 149   Vicente de Carvalho  POLYGON ((673.6210371174268 7471.098990690062,...
# 150               Vidigal  POLYGON ((681.0519644648174 7455.811778976163,...
# 151         Vigário Geral  POLYGON ((672.6899533280496 7475.581019272738,...
# 152           Vila Isabel  POLYGON ((678.6405754240654 7464.272398180444,...
# 153           Vila Kosmos  POLYGON ((673.6210371174268 7471.098990690062,...
# 154          Vila Militar  POLYGON ((663.6748797743683 7468.372804767359,...
# 155        Vila Valqueire  POLYGON ((667.4732974660285 7466.993447359994,...
# 156         Vila da Penha  POLYGON ((672.8379754859853 7472.217606969705,...
# 157          Vista Alegre  POLYGON ((673.523721291268 7473.969520745057, ...
# 158                 Zumbi  POLYGON ((687.2403577580452 7474.828526661353,...
# 159            Água Santa  POLYGON ((674.0974176221727 7465.184851280725,...
#
#          V002
# 0     11356.0
# 1     26967.0
# 2      9189.0
# 3     55634.0
# 4     39325.0
# 5     24156.0
# 6     12512.0
# 7    240666.0
# 8    135920.0
# 9      3545.0
# 10    14046.0
# 11    23698.0
# 12    43691.0
# 13    18341.0
# 14    82602.0
# 15    59218.0
# 16    42093.0
# 17    10997.0
# 18    20289.0
# 19     1953.0
# 20    10137.0
# 21   327905.0
# 22     1365.0
# 23    34347.0
# 24    24009.0
# 25    12482.0
# 26    16138.0
# 27    40834.0
# 28     5386.0
# 29     1475.0
# ..        ...
# 130    2741.0
# 131  105423.0
# 132   30570.0
# 133   56416.0
# 134   10980.0
# 135   24602.0
# 136    8307.0
# 137   37618.0
# 138  101739.0
# 139   29501.0
# 140  163095.0
# 141   24608.0
# 142   22671.0
# 143   17245.0
# 144    6760.0
# 145   14010.0
# 146   27212.0
# 147   15421.0
# 148   15167.0
# 149   24959.0
# 150   12788.0
# 151   41539.0
# 152   85770.0
# 153   18265.0
# 154   13147.0
# 155   32232.0
# 156   25462.0
# 157    8622.0
# 158    2016.0
# 159    7594.0
#
# [160 rows x 3 columns]

# %%
import os

dir = '../01.Dados/Mapas/RJ-BAIRRO'
if not os.path.exists(dir):
    os.makedirs(dir)
    
bairro.to_file(dir + '/RJ-BAIRRO.shp')
