# %% [markdown]
# # Arquitetura do Modelo 4

# %% [markdown]
# ## Etapa 1 - Importando as bibliotecas

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
import zipfile

cv2.__version__
# Out:
# '3.4.3'

# %%
# %tensorflow_version 2.x
import tensorflow
tensorflow.__version__
# Out:
# TensorFlow 2.x selected.
# '2.0.0'

# %% [markdown]
# ## Etapa 2 - Conectando com o Drive e acessando os arquivos

# %%
from google.colab import drive
drive.mount('/content/gdrive')
path = "/content/gdrive/My Drive/Material.zip"
zip_object = zipfile.ZipFile(file=path, mode="r")
zip_object.extractall("./")
base_imgs = 'Material/fer2013.zip'
zip_object = zipfile.ZipFile(file = base_imgs, mode = "r")
zip_object.extractall("./")
zip_object.close()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ## Etapa 3 - Acessando a base com fotos de expressões faciais

# %%
data = pd.read_csv('fer2013/fer2013.csv')
data.tail()
# Out:
#        emotion                                             pixels        Usage
# 35882        6  50 36 17 22 23 29 33 39 34 37 37 37 39 43 48 5...  PrivateTest
# 35883        3  178 174 172 173 181 188 191 194 196 199 200 20...  PrivateTest
# 35884        0  17 17 16 23 28 22 19 17 25 26 20 24 31 19 27 9...  PrivateTest
# 35885        3  30 28 28 29 31 30 42 68 79 81 77 67 67 71 63 6...  PrivateTest
# 35886        2  19 13 14 12 13 16 21 33 50 57 71 84 97 108 122...  PrivateTest

# %%
plt.figure(figsize=(12,6))
plt.hist(data['emotion'], bins=30)
plt.title("Imagens x emoção")

# Classes: ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
# Out:
# Text(0.5, 1.0, 'Imagens x emoção')

# %% [markdown]
# ## Etapa 4 - Pré-processamento

# %%
pixels = data['pixels'].tolist()
largura, altura = 48, 48

faces = []
amostras = 0 
for pixel_sequence in pixels:
  face = [int(pixel) for pixel in pixel_sequence.split(' ')]
  face = np.asarray(face).reshape(largura, altura) 
  faces.append(face)
  
  if (amostras < 10):
    cv2_imshow(face)

  amostras = amostras + 1

faces = np.asarray(faces) 
faces = np.expand_dims(faces, -1)

def normalizar(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    return x

faces = normalizar(faces)
emocoes = pd.get_dummies(data['emotion']).as_matrix()
# Out:
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F99DD8>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F23748>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31DA0>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31DA0>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31D68>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31DA0>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31E48>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31DA0>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31D68>
# <PIL.Image.Image image mode=L size=48x48 at 0x7FB6F8F31E80>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
print("Número total de imagens no dataset: "+str(len(faces)))
# Out:
# Número total de imagens no dataset: 35887

# %% [markdown]
# ## Etapa 5 - Imports do Tensorflow/Keras

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json

# %% [markdown]
# ## Etapa 6 - Dividir em conjuntos para treinamento e validação

# %%
x_train, x_test, y_train, y_test = train_test_split(faces, emocoes, test_size=0.1, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.1, random_state=41)

print("Número de imagens no conjunto de treinamento:", len(x_train))
print("Número de imagens no conjunto de testes:", len(x_test))
print("Número de imagens no conjunto de validação:", len(y_val))
# Out:
# Número de imagens no conjunto de treinamento: 29068
# Número de imagens no conjunto de testes: 3589
# Número de imagens no conjunto de validação: 3230

# %%
np.save('mod_xtest', x_test)
np.save('mod_ytest', y_test)

# %% [markdown]
# ## Etapa 7 - Arquitetura do Modelo (CNN)

# %% [markdown]
# ### Arquitetura do modelo

# %%
from tensorflow.keras import optimizers
epochs = 100
batch_size = 64
learning_rate = 0.001

model = Sequential()
    
model.add(Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1), kernel_regularizer=l2(0.01)))
model.add(Conv2D(64, (3, 3), padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2, 2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.5))
    
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
adam = optimizers.Adam(lr = learning_rate)
model.compile(optimizer = adam, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 9,014,727
# Trainable params: 9,009,223
# Non-trainable params: 5,504
# _________________________________________________________________
# None

# %% [markdown]
# ## Etapa 8 - Compilando o modelo

# %% [markdown]
# Vamos compilar o modelo e adicionar outras funções

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])
arquivo_modelo = "modelo_04_expressoes.h5" # arquivo do modelo
arquivo_modelo_json = "modelo_04_expressoes.json" # arquivo do json, para salvar a arquitetura
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=3, verbose=1)
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=8, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(arquivo_modelo, monitor='val_loss', verbose=1, save_best_only=True)

# %% [markdown]
# ### Salvando a arquitetura do modelo em um arquivo JSON

# %%
model_json = model.to_json()
with open(arquivo_modelo_json, "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ## Etapa 9 - Treinando o modelo

# %%
history = model.fit(np.array(x_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(x_val), np.array(y_val)),
          shuffle=True,
          callbacks=[lr_reducer, early_stopper, checkpointer])
# Out:
# Train on 29068 samples, validate on 3230 samples
# Epoch 1/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 2.0684 - accuracy: 0.1994
# Epoch 00001: val_loss improved from inf to 1.86005, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 74s 3ms/sample - loss: 2.0683 - accuracy: 0.1994 - val_loss: 1.8600 - val_accuracy: 0.2594
# Epoch 2/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8559 - accuracy: 0.2392
# Epoch 00002: val_loss improved from 1.86005 to 1.82873, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 65s 2ms/sample - loss: 1.8559 - accuracy: 0.2392 - val_loss: 1.8287 - val_accuracy: 0.2594
# Epoch 3/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8389 - accuracy: 0.2484
# Epoch 00003: val_loss improved from 1.82873 to 1.82073, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 65s 2ms/sample - loss: 1.8389 - accuracy: 0.2484 - val_loss: 1.8207 - val_accuracy: 0.2594
# Epoch 4/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8316 - accuracy: 0.2479
# Epoch 00004: val_loss improved from 1.82073 to 1.81249, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 65s 2ms/sample - loss: 1.8315 - accuracy: 0.2480 - val_loss: 1.8125 - val_accuracy: 0.2594
# Epoch 5/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8253 - accuracy: 0.2498
# Epoch 00005: val_loss improved from 1.81249 to 1.80791, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 65s 2ms/sample - loss: 1.8253 - accuracy: 0.2497 - val_loss: 1.8079 - val_accuracy: 0.2594
# Epoch 6/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8186 - accuracy: 0.2500
# Epoch 00006: val_loss improved from 1.80791 to 1.80105, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8186 - accuracy: 0.2500 - val_loss: 1.8011 - val_accuracy: 0.2594
# Epoch 7/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8148 - accuracy: 0.2509
# Epoch 00007: val_loss improved from 1.80105 to 1.79833, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8147 - accuracy: 0.2509 - val_loss: 1.7983 - val_accuracy: 0.2594
# Epoch 8/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8113 - accuracy: 0.2519
# Epoch 00008: val_loss improved from 1.79833 to 1.79654, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8113 - accuracy: 0.2519 - val_loss: 1.7965 - val_accuracy: 0.2594
# Epoch 9/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8061 - accuracy: 0.2516
# Epoch 00009: val_loss improved from 1.79654 to 1.78951, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8062 - accuracy: 0.2515 - val_loss: 1.7895 - val_accuracy: 0.2594
# Epoch 10/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8044 - accuracy: 0.2501
# Epoch 00010: val_loss improved from 1.78951 to 1.78596, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8044 - accuracy: 0.2501 - val_loss: 1.7860 - val_accuracy: 0.2594
# Epoch 11/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.8000 - accuracy: 0.2522
# Epoch 00011: val_loss improved from 1.78596 to 1.78271, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.8000 - accuracy: 0.2523 - val_loss: 1.7827 - val_accuracy: 0.2594
# Epoch 12/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.7823 - accuracy: 0.2640
# Epoch 00012: val_loss did not improve from 1.78271
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.7823 - accuracy: 0.2640 - val_loss: 1.7945 - val_accuracy: 0.2594
# Epoch 13/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.7326 - accuracy: 0.2901
# Epoch 00013: val_loss improved from 1.78271 to 1.76176, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.7326 - accuracy: 0.2900 - val_loss: 1.7618 - val_accuracy: 0.2799
# Epoch 14/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.6874 - accuracy: 0.3110
# Epoch 00014: val_loss improved from 1.76176 to 1.69088, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.6874 - accuracy: 0.3109 - val_loss: 1.6909 - val_accuracy: 0.3303
# Epoch 15/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.6240 - accuracy: 0.3356
# Epoch 00015: val_loss improved from 1.69088 to 1.52187, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.6240 - accuracy: 0.3356 - val_loss: 1.5219 - val_accuracy: 0.3944
# Epoch 16/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.5675 - accuracy: 0.3770
# Epoch 00016: val_loss did not improve from 1.52187
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.5675 - accuracy: 0.3769 - val_loss: 1.5348 - val_accuracy: 0.3969
# Epoch 17/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.5269 - accuracy: 0.3982
# Epoch 00017: val_loss did not improve from 1.52187
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.5269 - accuracy: 0.3982 - val_loss: 1.5773 - val_accuracy: 0.3693
# Epoch 18/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.4881 - accuracy: 0.4144
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00018: val_loss did not improve from 1.52187
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.4879 - accuracy: 0.4145 - val_loss: 1.5371 - val_accuracy: 0.3740
# Epoch 19/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.4465 - accuracy: 0.4209
# Epoch 00019: val_loss improved from 1.52187 to 1.42685, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.4465 - accuracy: 0.4209 - val_loss: 1.4269 - val_accuracy: 0.4229
# Epoch 20/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.4209 - accuracy: 0.4284
# Epoch 00020: val_loss did not improve from 1.42685
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.4208 - accuracy: 0.4285 - val_loss: 1.5639 - val_accuracy: 0.3536
# Epoch 21/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.3992 - accuracy: 0.4372
# Epoch 00021: val_loss improved from 1.42685 to 1.35805, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.3997 - accuracy: 0.4370 - val_loss: 1.3580 - val_accuracy: 0.4492
# Epoch 22/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.3803 - accuracy: 0.4492
# Epoch 00022: val_loss did not improve from 1.35805
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.3803 - accuracy: 0.4492 - val_loss: 1.3608 - val_accuracy: 0.4430
# Epoch 23/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.3634 - accuracy: 0.4520
# Epoch 00023: val_loss did not improve from 1.35805
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.3634 - accuracy: 0.4520 - val_loss: 1.3758 - val_accuracy: 0.4502
# Epoch 24/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.3422 - accuracy: 0.4654
# Epoch 00024: val_loss improved from 1.35805 to 1.31341, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.3422 - accuracy: 0.4654 - val_loss: 1.3134 - val_accuracy: 0.4786
# Epoch 25/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.3227 - accuracy: 0.4821
# Epoch 00025: val_loss did not improve from 1.31341
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.3230 - accuracy: 0.4820 - val_loss: 1.4086 - val_accuracy: 0.4539
# Epoch 26/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.2969 - accuracy: 0.4937
# Epoch 00026: val_loss improved from 1.31341 to 1.30310, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.2968 - accuracy: 0.4938 - val_loss: 1.3031 - val_accuracy: 0.4941
# Epoch 27/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.2701 - accuracy: 0.5134
# Epoch 00027: val_loss did not improve from 1.30310
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.2700 - accuracy: 0.5135 - val_loss: 1.3132 - val_accuracy: 0.4997
# Epoch 28/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.2390 - accuracy: 0.5251
# Epoch 00028: val_loss improved from 1.30310 to 1.20822, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.2397 - accuracy: 0.5250 - val_loss: 1.2082 - val_accuracy: 0.5418
# Epoch 29/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.2474 - accuracy: 0.5249
# Epoch 00029: val_loss did not improve from 1.20822
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.2474 - accuracy: 0.5249 - val_loss: 1.2433 - val_accuracy: 0.5396
# Epoch 30/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.2077 - accuracy: 0.5404
# Epoch 00030: val_loss improved from 1.20822 to 1.18925, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.2076 - accuracy: 0.5405 - val_loss: 1.1893 - val_accuracy: 0.5486
# Epoch 31/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.1786 - accuracy: 0.5520
# Epoch 00031: val_loss did not improve from 1.18925
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.1795 - accuracy: 0.5519 - val_loss: 1.2390 - val_accuracy: 0.5359
# Epoch 32/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.1645 - accuracy: 0.5596
# Epoch 00032: val_loss improved from 1.18925 to 1.18218, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.1649 - accuracy: 0.5596 - val_loss: 1.1822 - val_accuracy: 0.5601
# Epoch 33/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.1555 - accuracy: 0.5667
# Epoch 00033: val_loss improved from 1.18218 to 1.14924, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.1556 - accuracy: 0.5667 - val_loss: 1.1492 - val_accuracy: 0.5718
# Epoch 34/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.1280 - accuracy: 0.5748
# Epoch 00034: val_loss did not improve from 1.14924
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.1282 - accuracy: 0.5746 - val_loss: 1.1643 - val_accuracy: 0.5464
# Epoch 35/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.1060 - accuracy: 0.5833
# Epoch 00035: val_loss did not improve from 1.14924
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.1059 - accuracy: 0.5834 - val_loss: 1.1505 - val_accuracy: 0.5755
# Epoch 36/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.0912 - accuracy: 0.5869
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00036: val_loss did not improve from 1.14924
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.0914 - accuracy: 0.5868 - val_loss: 1.1613 - val_accuracy: 0.5820
# Epoch 37/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.0669 - accuracy: 0.6047
# Epoch 00037: val_loss improved from 1.14924 to 1.14567, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.0671 - accuracy: 0.6047 - val_loss: 1.1457 - val_accuracy: 0.5889
# Epoch 38/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.0577 - accuracy: 0.6046
# Epoch 00038: val_loss did not improve from 1.14567
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.0578 - accuracy: 0.6045 - val_loss: 1.1472 - val_accuracy: 0.5935
# Epoch 39/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.0449 - accuracy: 0.6125
# Epoch 00039: val_loss did not improve from 1.14567
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.0448 - accuracy: 0.6126 - val_loss: 1.1468 - val_accuracy: 0.6012
# Epoch 40/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 1.0134 - accuracy: 0.6244
# Epoch 00040: val_loss improved from 1.14567 to 1.11576, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 1.0133 - accuracy: 0.6245 - val_loss: 1.1158 - val_accuracy: 0.5960
# Epoch 41/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.9890 - accuracy: 0.6330
# Epoch 00041: val_loss did not improve from 1.11576
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.9889 - accuracy: 0.6331 - val_loss: 1.2675 - val_accuracy: 0.5687
# Epoch 42/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.9763 - accuracy: 0.6391
# Epoch 00042: val_loss did not improve from 1.11576
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.9765 - accuracy: 0.6391 - val_loss: 1.1482 - val_accuracy: 0.5978
# Epoch 43/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.9570 - accuracy: 0.6482
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00043: val_loss did not improve from 1.11576
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.9568 - accuracy: 0.6482 - val_loss: 1.1586 - val_accuracy: 0.6090
# Epoch 44/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.9346 - accuracy: 0.6575
# Epoch 00044: val_loss did not improve from 1.11576
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.9345 - accuracy: 0.6575 - val_loss: 1.1256 - val_accuracy: 0.5981
# Epoch 45/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.9160 - accuracy: 0.6680
# Epoch 00045: val_loss improved from 1.11576 to 1.10563, saving model to modelo_04_expressoes.h5
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.9158 - accuracy: 0.6680 - val_loss: 1.1056 - val_accuracy: 0.6155
# Epoch 46/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8914 - accuracy: 0.6744
# Epoch 00046: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.8915 - accuracy: 0.6743 - val_loss: 1.1188 - val_accuracy: 0.6053
# Epoch 47/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8801 - accuracy: 0.6794
# Epoch 00047: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.8800 - accuracy: 0.6795 - val_loss: 1.1435 - val_accuracy: 0.6056
# Epoch 48/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8773 - accuracy: 0.6817
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 00048: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.8774 - accuracy: 0.6816 - val_loss: 1.1895 - val_accuracy: 0.5997
# Epoch 49/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8488 - accuracy: 0.6962
# Epoch 00049: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.8487 - accuracy: 0.6962 - val_loss: 1.1512 - val_accuracy: 0.6146
# Epoch 50/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8400 - accuracy: 0.6987
# Epoch 00050: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 63s 2ms/sample - loss: 0.8406 - accuracy: 0.6987 - val_loss: 1.1578 - val_accuracy: 0.6124
# Epoch 51/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.8295 - accuracy: 0.7061
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 00051: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.8294 - accuracy: 0.7061 - val_loss: 1.2000 - val_accuracy: 0.6164
# Epoch 52/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.7988 - accuracy: 0.7161
# Epoch 00052: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.7989 - accuracy: 0.7161 - val_loss: 1.1695 - val_accuracy: 0.6186
# Epoch 53/100
# 29056/29068 [============================>.] - ETA: 0s - loss: 0.7769 - accuracy: 0.7267
# Epoch 00053: val_loss did not improve from 1.10563
# 29068/29068 [==============================] - 64s 2ms/sample - loss: 0.7771 - accuracy: 0.7267 - val_loss: 1.2187 - val_accuracy: 0.6263
# Epoch 00053: early stopping

# %% [markdown]
# ## Gerando gráfico da melhora em cada etapa do treinamento

# %%
def plota_historico_modelo(historico_modelo):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    axs[0].plot(range(1,len(historico_modelo.history['accuracy'])+1),
                historico_modelo.history['accuracy'],'r')
    axs[0].plot(range(1,len(historico_modelo.history['val_accuracy'])+1),
                historico_modelo.history['val_accuracy'],'b')
    axs[0].set_title('Acurácia do Modelo')
    axs[0].set_ylabel('Acuracia')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(historico_modelo.history['accuracy'])+1),
                      len(historico_modelo.history['accuracy'])/10)
    axs[0].legend(['training accuracy', 'validation accuracy'], loc='best')

    axs[1].plot(range(1,len(historico_modelo.history['loss'])+1),
                historico_modelo.history['loss'],'r')
    axs[1].plot(range(1,len(historico_modelo.history['val_loss'])+1),
                historico_modelo.history['val_loss'],'b')
    axs[1].set_title('Perda/Loss do Modelo')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(historico_modelo.history['loss'])+1),
                      len(historico_modelo.history['loss'])/10)
    axs[1].legend(['training loss', 'validation Loss'], loc='best')
    fig.savefig('historico_modelo_mod01.png')
    plt.show()

plota_historico_modelo(history)

# %% [markdown]
# ### Verificando a acurácia do modelo

# %%
scores = model.evaluate(np.array(x_test), np.array(y_test), batch_size=batch_size)
print("Acurácia: " + str(scores[1]))
print("Perda/Loss: " + str(scores[0]))
# Out:
# 3589/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Acurácia: 0.611591
# Perda/Loss: 1.2445896523481759

# %% [markdown]
# ## Carregaremos os dados para gerar a matriz de confusão

# %%
true_y=[]
pred_y=[]
x = np.load('mod_xtest.npy')
y = np.load('mod_ytest.npy')
json_file = open(arquivo_modelo_json, 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights(arquivo_modelo)
y_pred= loaded_model.predict(x)
yp = y_pred.tolist()
yt = y.tolist()
count = 0
for i in range(len(y)):
    yy = max(yp[i])
    yyt = max(yt[i])
    pred_y.append(yp[i].index(yy))
    true_y.append(yt[i].index(yyt))
    if(yp[i].index(yy)== yt[i].index(yyt)):
        count+=1
acc = (count/len(y))*100
np.save('truey__mod01', true_y)
np.save('predy__mod01', pred_y)
print("Acurácia no conjunto de testes: "+str(acc)+"%")
# Out:
# Acurácia no conjunto de testes: 59.76595151852884%

# %% [markdown]
# ## Gerando a Matriz de Confusão

# %%
from sklearn.metrics import confusion_matrix
y_true = np.load('truey__mod01.npy')
y_pred = np.load('predy__mod01.npy')
cm = confusion_matrix(y_true, y_pred)
expressoes = ["Raiva", "Nojo", "Medo", "Feliz", "Triste", "Surpreso", "Neutro"]
titulo='Matriz de Confusão'
print(cm)
# Out:
# [[217   0  32  18 157   5  69]
#  [ 38   0   4   0   6   1   3]
#  [ 62   0 185  17 197  22  62]
#  [ 12   0  17 722  35   5  90]
#  [ 30   0  30  12 383   0 133]
#  [  5   0 101  37  16 235  20]
#  [  8   0  18  33 148   1 403]]

# %%
import itertools
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title(titulo)
plt.colorbar()
tick_marks = np.arange(len(expressoes))
plt.xticks(tick_marks, expressoes, rotation=45)
plt.yticks(tick_marks, expressoes)
fmt = 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

plt.ylabel('Classificação Correta')
plt.xlabel('Predição')
plt.savefig('matriz_confusao_mod01.png')
plt.show()

# %% [markdown]
# ## Testando brevemente o modelo

# %%
imagem = cv2.imread("Material/testes/teste02.jpg")
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=754x395 at 0x7FB69169D358>

# %%
model = load_model("modelo_04_expressoes.h5")
scores = model.evaluate(np.array(x_test), np.array(y_test), batch_size=batch_size)
print("Perda/Loss: " + str(scores[0]))
print("Acurácia: " + str(scores[1]))
# Out:
# 3589/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# Perda/Loss: 1.1682684752694674
# Acurácia: 0.5976595

# %%
expressoes = ["Raiva", "Nojo", "Medo", "Feliz", "Triste", "Surpreso", "Neutro"]
original = imagem.copy()
gray = cv2.cvtColor(original, cv2.COLOR_BGR2GRAY)
face_cascade = cv2.CascadeClassifier('Material/haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(gray, 1.1, 3)
for (x, y, w, h) in faces:
    cv2.rectangle(original, (x, y), (x + w, y + h), (0, 255, 0), 1)
    roi_gray = gray[y:y + h, x:x + w]
    roi_gray = roi_gray.astype("float") / 255.0
    cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
    cv2.normalize(cropped_img, cropped_img, alpha=0, beta=1, 
                  norm_type=cv2.NORM_L2, dtype=cv2.CV_32F)
    prediction = model.predict(cropped_img)[0]
    cv2.putText(original, expressoes[int(np.argmax(prediction))], (x, y - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2, cv2.LINE_AA)
cv2_imshow(original)
# Out:
# <PIL.Image.Image image mode=RGB size=754x395 at 0x7FB682342C88>
